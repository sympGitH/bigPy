# %%
import pandas as pd

# %%
# %matplotlib inline

# %% [markdown]
# 한글이 잘 표현되는 글씨체를 matplotlib에서 설정을 해야 한글이 깨지지 않습니다.

# %%
import matplotlib as mpl
mpl.rcParams['font.family']='AppleMyungjo'

# %%
시리즈=pd.Series([1, 2, 3], index=['가', '나', '다'])

# %%
시리즈
# Out:
# 가    1
# 나    2
# 다    3
# dtype: int64

# %%
시리즈.plot(title='테스트', kind='bar')

# %%
# 설치된 폰트리스트를 볼 수 있는 예제
for font in mpl.font_manager.fontManager.ttflist:
    print (font)
# Out:
# <Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>
# <Font 'cmb10' (cmb10.ttf) normal normal 400 normal>
# <Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>
# <Font 'Bitstream Vera Sans' (Vera.ttf) normal normal 400 normal>
# <Font 'Bitstream Vera Sans' (VeraBd.ttf) normal normal 700 normal>
# <Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>
# <Font 'Bitstream Vera Sans' (VeraBI.ttf) oblique normal 700 normal>
# <Font 'cmss10' (cmss10.ttf) normal normal 400 normal>
# <Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>
# <Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>
# <Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>
# <Font 'Bitstream Vera Sans Mono' (VeraMoBI.ttf) oblique normal 700 normal>
# <Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>
# <Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>
# ...

# %%
# !pip install mpld3
# Out:
# ...
#     100% |████████████████████████████████| 1.1MB 456kB/s
# ...
# done
#   Stored in directory: /Users/Koon/Library/Caches/pip/wheels/3b/a2/2b/4985580503d9f874a5bfa1722cb14c56193c60d48ab4fb50a7
# Successfully built mpld3
# ...
# You are using pip version 8.1.1, however version 8.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# 그래프는... 아래의 mpld3 를 활용하여 작업하는 것도 좋음
import mpld3
from mpld3 import plugins
import matplotlib.pyplot as plt

# %%
import sys, os
# 절대경로를 알려줌 - '/Users/Koon/Documents/bigpy/modules'
sys.path.append(os.path.abspath('./modules/'))
from NC import importNC

# %%
#NC=importNC('./data/')
#NCG=NC[0]['안타']
#NC13=NC[0]
NC13 = NC13.reset_index()
NC13_G = NC[0].ix[:,['안타','홈런', '타석']]

# %%
#mpld3.display(NC13_G)
NC13_G[:10]
# Out:
#       안타  홈런   타석
# 선수명
# 모창민  109  12  436
# 이호준  123  20  508
# 김종호  129   0  546
# 나성범   98  14  458
# 조영훈  107   6  426
# 이현곤   38   0  161
# 이상호   31   0  138
# 강진성    1   0    3
# 조평호   21   2   86
# 박민우   11   0   48

# %%
def 요일추출(날짜):
    return 날짜.weekDay()

# %% [markdown]
# ## 시계열

# %%
식당=pd.read_excel('./data/food_order.xlsx')

# %%
len(식당)
# Out:
# 6825

# %%
식당=식당.set_index('date')

# %%
식당[:3]
# Out:
#            dine_type         corner          menu is_sold_out  use_count  \
# date
# 2013-08-06    dinner    grill & fry  훈제연어벤또(200개)           F        213
# 2013-08-06    dinner  rice & soup 1   뚝배기 우거지 갈비탕           F        261
# 2013-08-06     lunch     noodle bar         판모밀정식           F        267
#
#             pred_count  additional  good  ok  bad  diff_use_pred  year  month  \
# date
# 2013-08-06           0           0     0   0    0           -213  2013      8
# 2013-08-06           0           0     0   0    0           -261  2013      8
# 2013-08-06           0           0     0   0    0           -267  2013      8
#
#             day  wday
# date
# 2013-08-06    6     1
# 2013-08-06    6     1
# 2013-08-06    6     1

# %%
식당.ix['2013-08-06']
# Out:
#             dine_type         corner          menu is_sold_out  use_count  \
# date
# 2013-08-06     dinner    grill & fry  훈제연어벤또(200개)           F        213
# 2013-08-06     dinner  rice & soup 1   뚝배기 우거지 갈비탕           F        261
# 2013-08-06      lunch     noodle bar         판모밀정식           F        267
# 2013-08-06  breakfast  rice & soup 1         설렁탕정식           F          1
# 2013-08-06      lunch  rice & soup 1     A. 부대찌개정식           F        376
#
#             pred_count  additional  good  ok  bad  diff_use_pred  year  month  \
# date
# 2013-08-06           0           0     0   0    0           -213  2013      8
# 2013-08-06           0           0     0   0    0           -261  2013      8
# 2013-08-06           0           0     0   0    0           -267  2013      8
# 2013-08-06           0           0     0   0    0             -1  2013      8
# 2013-08-06           0           0     0   0    0           -376  2013      8
#
#             day  wday
# date
# ...

# %%
식당.ix['2014-08']
# Out:
#             dine_type         corner            menu is_sold_out  use_count  \
# date
# 2014-08-01     dinner   after school      햄모듬라면&콩도너츠           F        137
# 2014-08-01      lunch   after school     카레라면&비빔채소만두           T        129
# 2014-08-01     dinner    grill & fry        취나물밥&양념장           F         68
# 2014-08-01  breakfast       take out         7곡빵샌드위치           F         39
# 2014-08-01      lunch    grill & fry           더덕비빔밥           F        158
# 2014-08-01     dinner     noodle bar    냉메밀소바&김가루양념밥           T        121
# 2014-08-01     dinner       take out    김치볶음밥&스크램블에그           F        341
# 2014-08-01  breakfast  rice & soup 1             닭곰탕           F         40
# 2014-08-01      lunch     noodle bar            초계국수           T        136
# 2014-08-01     dinner  rice & soup 1             육개장           T        141
# 2014-08-01      lunch   burger&pizza          고구마돈가스           T        267
# ...

# %%
식당.ix['2014'][:10]
# Out:
#             dine_type         corner           menu is_sold_out  use_count  \
# date
# 2014-01-02  breakfast       take out       쿡살라미샌드위치           F         51
# 2014-01-02     dinner     noodle bar        오징어비빔국수           F        111
# 2014-01-02     dinner       take out      날치알캘리포니아롤           F        386
# 2014-01-02      lunch   burger&pizza        갈릭오일파스타           T        142
# 2014-01-02     dinner   burger&pizza        참치김치그라탕           T        151
# 2014-01-02  breakfast  rice & soup 1        전주콩나물국밥           F         51
# 2014-01-02      lunch     noodle bar      구로쇼유베이컨라멘           T        246
# 2014-01-02     dinner    grill & fry         장조림도시락           T        168
# 2014-01-02      lunch   after school  스팸김치철판볶음밥 set           T        203
# 2014-01-02      lunch    grill & fry         치킨마요덮밥           T        220
#
#             pred_count  additional  good  ok  bad  diff_use_pred  year  month  \
# date
# ...
